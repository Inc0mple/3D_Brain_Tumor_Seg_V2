# %%
from tqdm import tqdm
import os
import time
from datetime import datetime
from random import randint

import numpy as np
from scipy import stats
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.model_selection import KFold

import nibabel as nib

import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.animation as anim
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec

import seaborn as sns
from skimage.transform import resize
from skimage.util import montage

from IPython.display import Image as show_gif
from IPython.display import clear_output

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

from torch.optim import Adam, AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau

import re
import warnings


warnings.simplefilter("ignore")

# %%
from utils.Meter import Meter, DiceLoss, BCEDiceLoss, dice_coef_metric_per_classes, jaccard_coef_metric_per_classes

# CAN POTENTIALLY TRY DIFFERENT AUGMENTATION TECHNIQUES HERE
from utils.BratsDataset import BratsDataset

from utils.Meter import BCEDiceLoss

from models.UNet3d import UNet3d
from models.UNet3dDropout import UNet3dDropout
from models.SwinUNETR import SwinUNETR
from models.UNet3d_your_modifications import UNet3d_your_modifications
from models.UNet3d_SELU import UNet3d_SELU
from models.UNet3d_atten import UNet3d_atten
from models.ONet3d import ONet3d
from models.ONet3d_v2 import ONet3d_v2
from models.ONet3d_v3 import ONet3d_v3
from models.ONet3d_v3_DoubleConv import ONet3d_v3_DoubleConv
from models.UNet3d_GELU import UNet3d_GELU
from models.ONet3d_v3_GELU import ONet3d_v3_GELU
from models.SphereNet3d import SphereNet3d
# from models.SphereNet3d_GELU import SphereNet3d_GELU

# %%
def get_losses(filename):

  # open the text file
  with open(filename, 'r') as f:
      contents = f.read()

  # extract the train losses and val losses using regular expressions
  train_losses_str = re.search(r"losses:{'train': (.+?), 'val'", contents).group(1)
  val_losses_str = re.search(r"'val': \[(.+?)\}", contents).group(1)

  train_losses_str = train_losses_str.replace('[', '').replace(']', '')
  val_losses_str = val_losses_str.replace('[', '').replace(']', '')

  # convert the strings to lists of floating-point numbers
  train_losses = [float(x.strip()) for x in train_losses_str.split(', ')]
  val_losses = [float(x.strip()) for x in val_losses_str.split(', ')]
  
  print(f"{len(train_losses)} train and {len(val_losses)} val losses found in {filename}")

  # print the lists
  return train_losses, val_losses





def get_param_count(filename):

  # open the text file
  with open(filename, 'r') as f:
      contents = f.read()

  # extract the param count using regular expressions
  param_str = re.search(
      r"(?<=parameter_count:).*", contents).group(0)
  param_count = int(param_str)
  print(f"Parameter count = {param_count} in {filename}")
  
  return param_count


def get_dice_scores(filename):

  # open the text file
  with open(filename, 'r') as f:
      lines = f.readlines()
      
  for line in lines:
    if "dice_scores" in line:

    # extract the dice scores and iou scores using regular expressions
      train_dice_str = re.search(
          r"'train': (.+?), 'val'", line).group(1)
      val_dice_str = re.search(r"'val': \[(.+?)\}", line).group(1)

      train_dice_str = train_dice_str.replace('[', '').replace(']', '')
      val_dice_str = val_dice_str.replace('[', '').replace(']', '')

      # convert the strings to lists of floating-point numbers
      train_dice = [float(x.strip()) for x in train_dice_str.split(', ')]
      val_dice = [float(x.strip()) for x in val_dice_str.split(', ')]
      break
  print(f"{len(train_dice)} train and {len(val_dice)} val dice score found in {filename}")
  return train_dice, val_dice


def get_jaccard_scores(filename):

  # open the text file
  with open(filename, 'r') as f:
      lines = f.readlines()

  for line in lines:
    if "jaccard_scores" in line:

      # extract the dice scores and iou scores using regular expressions
      train_jaccard_str = re.search(
          r"'train': (.+?), 'val'", line).group(1)
      val_jaccard_str = re.search(r"'val': \[(.+?)\}", line).group(1)

      train_jaccard_str = train_jaccard_str.replace('[', '').replace(']', '')
      val_jaccard_str = val_jaccard_str.replace('[', '').replace(']', '')

      # convert the strings to lists of floating-point numbers
      train_jaccard = [float(x.strip()) for x in train_jaccard_str.split(', ')]
      val_jaccard = [float(x.strip()) for x in val_jaccard_str.split(', ')]
      break
  print(f"{len(train_jaccard)} train and {len(val_jaccard)} val jaccard score found in {filename}")
  return train_jaccard, val_jaccard

def get_train_run_time(filename):

  # open the text file
  with open(filename, 'r') as f:
      contents = f.read()

  # extract the param count using regular expressions
  time_str = re.search(
      r"(?<=last_completed_run_time:).*(?=\n)", contents).group(0)
  time_obj = datetime.strptime(time_str, "%H:%M:%S.%f").time()
  print(f"Trainer runtime = {time_obj} in {filename}")
  return time_obj

FILENAME = "Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt"

get_param_count(FILENAME)
get_train_run_time(FILENAME)
get_losses(FILENAME)
get_dice_scores(FILENAME)
get_jaccard_scores(FILENAME)
print("Test done")
# Out:
# Parameter count = 5896515 in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# Trainer runtime = 05:51:38.640594 in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# Test done

# %%
results_dict = {}

for dirname in os.listdir("Logs"):
  model_name = dirname
  results_dict[model_name] = {}
  
  filename = f"Logs/{dirname}/trainer_properties.txt"
  parameter_count = get_param_count(filename)
  trainer_runtime = get_train_run_time(filename)
  train_losses, val_losses = get_losses(filename)
  train_dices, val_dices = get_dice_scores(filename)
  train_jaccards, val_jacards = get_jaccard_scores(filename)
  results_dict[model_name]["parameter_count"] = parameter_count
  results_dict[model_name]["trainer_runtime"] = trainer_runtime
  results_dict[model_name]["train_losses"] = train_losses
  results_dict[model_name]["val_losses"] = val_losses
  results_dict[model_name]["train_dices"] = train_dices
  results_dict[model_name]["val_dices"] = val_dices
  results_dict[model_name]["train_jaccards"] = train_jaccards
  results_dict[model_name]["val_jacards"] = val_jacards
# Out:
# Parameter count = 5597571 in Logs/3DOnet_SingleConv_Kernel1_32_Channels/trainer_properties.txt
# Trainer runtime = 12:10:09.814454 in Logs/3DOnet_SingleConv_Kernel1_32_Channels/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DOnet_SingleConv_Kernel1_32_Channels/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DOnet_SingleConv_Kernel1_32_Channels/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DOnet_SingleConv_Kernel1_32_Channels/trainer_properties.txt
# Parameter count = 6134019 in Logs/SphereNet3D/trainer_properties.txt
# Trainer runtime = 10:27:29.978756 in Logs/SphereNet3D/trainer_properties.txt
# 50 train and 50 val losses found in Logs/SphereNet3D/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/SphereNet3D/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/SphereNet3D/trainer_properties.txt
# Parameter count = 3150435 in Logs/3DOnet_SingleConv_Kernel1_GELU_AdamW/trainer_properties.txt
# Trainer runtime = 07:45:28.808567 in Logs/3DOnet_SingleConv_Kernel1_GELU_AdamW/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DOnet_SingleConv_Kernel1_GELU_AdamW/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DOnet_SingleConv_Kernel1_GELU_AdamW/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DOnet_SingleConv_Kernel1_GELU_AdamW/trainer_properties.txt
# Parameter count = 14981601 in Logs/SwinUNETR_AdamW/trainer_properties.txt
# Trainer runtime = 06:48:20.114492 in Logs/SwinUNETR_AdamW/trainer_properties.txt
# 50 train and 50 val losses found in Logs/SwinUNETR_AdamW/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/SwinUNETR_AdamW/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/SwinUNETR_AdamW/trainer_properties.txt
# Parameter count = 6094231 in Logs/3DUnet_Atten/trainer_properties.txt
# Trainer runtime = 03:37:32.812110 in Logs/3DUnet_Atten/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DUnet_Atten/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DUnet_Atten/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DUnet_Atten/trainer_properties.txt
# Parameter count = 3150435 in Logs/3DOnet_SingleConv_Kernel1/trainer_properties.txt
# Trainer runtime = 10:32:40.717688 in Logs/3DOnet_SingleConv_Kernel1/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DOnet_SingleConv_Kernel1/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DOnet_SingleConv_Kernel1/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DOnet_SingleConv_Kernel1/trainer_properties.txt
# Parameter count = 14981601 in Logs/SwinUNETR/trainer_properties.txt
# Trainer runtime = 04:06:28.977779 in Logs/SwinUNETR/trainer_properties.txt
# 50 train and 50 val losses found in Logs/SwinUNETR/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/SwinUNETR/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/SwinUNETR/trainer_properties.txt
# Parameter count = 5896515 in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# Trainer runtime = 05:51:38.640594 in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DOnet_DoubleConv_Kernel1/trainer_properties.txt
# Parameter count = 5652507 in Logs/3DUnet_Dropout/trainer_properties.txt
# Trainer runtime = 03:53:35.505063 in Logs/3DUnet_Dropout/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DUnet_Dropout/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DUnet_Dropout/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DUnet_Dropout/trainer_properties.txt
# Parameter count = 5652507 in Logs/3DUnet_SELU/trainer_properties.txt
# Trainer runtime = 03:34:44.640158 in Logs/3DUnet_SELU/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DUnet_SELU/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DUnet_SELU/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DUnet_SELU/trainer_properties.txt
# Parameter count = 5652507 in Logs/3DUnet/trainer_properties.txt
# Trainer runtime = 04:38:10.980250 in Logs/3DUnet/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DUnet/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DUnet/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DUnet/trainer_properties.txt
# Parameter count = 10045731 in Logs/3DUnet_32_Channels/trainer_properties.txt
# Trainer runtime = 05:19:13.541999 in Logs/3DUnet_32_Channels/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DUnet_32_Channels/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DUnet_32_Channels/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DUnet_32_Channels/trainer_properties.txt
# Parameter count = 3150435 in Logs/3DOnet_SingleConv_Kernel1_GELU/trainer_properties.txt
# Trainer runtime = 06:39:10.236862 in Logs/3DOnet_SingleConv_Kernel1_GELU/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DOnet_SingleConv_Kernel1_GELU/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DOnet_SingleConv_Kernel1_GELU/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DOnet_SingleConv_Kernel1_GELU/trainer_properties.txt
# Parameter count = 15639711 in Logs/SwinUNETR_DoubleLayerDepth/trainer_properties.txt
# Trainer runtime = 15:14:58.148519 in Logs/SwinUNETR_DoubleLayerDepth/trainer_properties.txt
# 50 train and 50 val losses found in Logs/SwinUNETR_DoubleLayerDepth/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/SwinUNETR_DoubleLayerDepth/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/SwinUNETR_DoubleLayerDepth/trainer_properties.txt
# Parameter count = 5652507 in Logs/3DUnet_GELU/trainer_properties.txt
# Trainer runtime = 05:50:58.570332 in Logs/3DUnet_GELU/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DUnet_GELU/trainer_properties.txt
# 50 train and 50 val dice score found in Logs/3DUnet_GELU/trainer_properties.txt
# 50 train and 50 val jaccard score found in Logs/3DUnet_GELU/trainer_properties.txt
# Parameter count = 16863843 in Logs/3DOnet_SingleConv_Kernel5/trainer_properties.txt
# Trainer runtime = 10:01:18.950033 in Logs/3DOnet_SingleConv_Kernel5/trainer_properties.txt
# 50 train and 50 val losses found in Logs/3DOnet
.1875569811969433, 0.19990583804418455, 0.17098185560613308, 0.16725331826030082, 0.16574513933287477, 0.16596663553478583, 0.16565456424119337, 0.1658209665625725, 0.1660187730811677, 0.16528771248347354, 0.1648436537328756, 0.16453555134950942, 0.16526469103289101, 0.16482626414805088, 0.16413797649010173, 0.16343212183916345, 0.1665699488290076, 0.1656187966747104, 0.16413699378663638, 0.16293531860101898, 0.16247559373952308, 0.1624483659441741], 'train_dices': [0.42105302, 0.5630951, 0.62336135, 0.6679892, 0.60852015, 0.62267977, 0.5996599, 0.55647075, 0.51190495, 0.49304652, 0.6090247, 0.6854851, 0.778473, 0.7884975, 0.77494705, 0.7922623, 0.81466955, 0.82739156, 0.8362616, 0.8283593, 0.83834475, 0.8397578, 0.8421003, 0.8534145, 0.85522974, 0.85526067, 0.85644805, 0.85969466, 0.8633914, 0.865907, 0.8648281, 0.8769906, 0.8802887, 0.8825736, 0.8838739, 0.8853196, 0.8868493, 0.8875338, 0.88815933, 0.889194, 0.8903491, 0.8911265, 0.8913471, 0.89232194, 0.8928647, 0.89320946, 0.893675, 0.8956027, 0.8958148, 0.89600796], 'val_dices': [0.35238284, 0.5900733, 0.60498625, 0.6563071, 0.62285095, 0.6280931, 0.5114139, 0.5072928, 0.52106106, 0.58240014, 0.65558404, 0.7406539, 0.7379428, 0.78455603, 0.74700767, 0.7955485, 0.80821145, 0.8162045, 0.8162085, 0.8177384, 0.81209636, 0.818836, 0.8248588, 0.8309363, 0.82742715, 0.8336982, 0.835567, 0.83027256, 0.8335898, 0.821563, 0.8484095, 0.8515617, 0.8526614, 0.8523529, 0.8524475, 0.85226846, 0.8522293, 0.8527838, 0.8533034, 0.8533323, 0.85272205, 0.853073, 0.8536016, 0.8543482, 0.85133976, 0.85202974, 0.8535278, 0.8546496, 0.85506254, 0.8550908], 'train_jaccards': [0.29168823, 0.40907568, 0.46888712, 0.51664835, 0.4517912, 0.4640149, 0.44105798, 0.3963083, 0.3560417, 0.3388019, 0.4504546, 0.53263676, 0.6504463, 0.66338825, 0.64819443, 0.66949815, 0.699167, 0.71482587, 0.7263956, 0.7160641, 0.7309909, 0.7320546, 0.73489344, 0.75112766, 0.7538539, 0.75380504, 0.7558166, 0.7605164, 0.7654675, 0.76960385, 0.76831156, 0.78583455, 0.79050356, 0.79400575, 0.79595006, 0.7981122, 0.8004033, 0.8013757, 0.80229115, 0.80392057, 0.8056449, 0.80691373, 0.80723214, 0.80870634, 0.80958605, 0.81011057, 0.81083184, 0.8138304, 0.8141723, 0.8144795], 'val_jacards': [0.23547375, 0.43514517, 0.44883657, 0.5024263, 0.4642348, 0.469046 ...

# %%
def plot_param_count(results_dict = results_dict):
  x = []
  y = []
  for model_name in results_dict:
    x.append(model_name)
    y.append(results_dict[model_name]["parameter_count"])
  
  # sort based on ascending order of parameter count
  x = [val for _, val in sorted(zip(y, x))]
  y = sorted(y)
  
  fig, ax = plt.subplots(figsize=(12, 8))
  ax.set_title("Model Parameter Count")
  sns.barplot(x=x, y=y)
  ax.set_xlabel("Models")
  ax.set_ylabel("Parameter Count")
  ax.legend()
  plt.xticks(rotation=45, ha='right')
  plt.show()


plot_param_count()
# Out:
# 2023-03-20 09:27:05,518 - No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.dates as mdates
def plot_trainer_runtime(results_dict=results_dict):
  x = []
  y = []
  for model_name in results_dict:
    x.append(model_name)
    y.append(results_dict[model_name]["trainer_runtime"])

  # sort based on ascending order of parameter count
  x = [val for _, val in sorted(zip(y, x))]
  y = sorted(y)
  # today = datetime.datetime.now()
  # y = [datetime.datetime.combine(today, t) for t in y]
  print(y)
  fig, ax = plt.subplots(figsize=(12, 8))
  ax.set_title("Model Trainer Runtime")
  plt.bar(x, y)
  ax.set_xlabel("Models")
  ax.set_ylabel("Trainer Runtime")
  ax.legend()
  plt.xticks(rotation=45, ha='right')
  plt.show()


plot_trainer_runtime()
# Out:
# [datetime.time(3, 34, 44, 640158), datetime.time(3, 37, 32, 812110), datetime.time(3, 53, 35, 505063), datetime.time(4, 6, 28, 977779), datetime.time(4, 38, 10, 980250), datetime.time(5, 19, 13, 541999), datetime.time(5, 50, 58, 570332), datetime.time(5, 51, 38, 640594), datetime.time(6, 39, 10, 236862), datetime.time(6, 48, 20, 114492), datetime.time(7, 45, 28, 808567), datetime.time(10, 1, 18, 950033), datetime.time(10, 27, 29, 978756), datetime.time(10, 32, 40, 717688), datetime.time(12, 10, 9, 814454), datetime.time(14, 10, 39, 161235), datetime.time(15, 14, 58, 148519)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_17680/2387253077.py in <module>
#      23
#      24
# ---> 25 plot_trainer_runtime()
#
# /tmp/ipykernel_17680/2387253077.py in plot_trainer_runtime(results_dict)
#      15   fig, ax = plt.subplots(figsize=(12, 8))
#      16   ax.set_title("Model Trainer Runtime")
# ---> 17   plt.bar(x, y)
#      18   ax.set_xlabel("Models")
#      19   ax.set_ylabel("Trainer Runtime")
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2397         x, height, width=0.8, bottom=None, *, align='center',
#    2398         data=None, **kwargs):
# -> 2399     return gca().bar(
#    2400         x, height, width=width, bottom=bottom, align=align,
#    2401         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2393                    hatch)
#    2394         for l, b, w, h, c, e, lw, htch in args:
# -> 2395             r = mpatches.Rectangle(
#    2396                 xy=(l, b), width=w, height=h,
#    2397                 facecolor=c,
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     737         self._height = height
#     738         self.angle = float(angle)
# --> 739         self._convert_units()  # Validate the inputs.
#     740
#     741     def get_path(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in _convert_units(self)
#     748         y0 = self.convert_yunits(self._y0)
#     749         x1 = self.convert_xunits(self._x0 + self._width)
# --> 750         y1 = self.convert_yunits(self._y0 + self._height)
#     751         return x0, y0, x1, y1
#     752
#
# TypeError: unsupported operand type(s) for +: 'int' and 'datetime.time'

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import datetime

# create sample data
times = [datetime.time(np.random.randint(0, 24), np.random.randint(
    0, 60), np.random.randint(0, 60)) for _ in range(10)]
values = np.random.rand(10)
df = pd.DataFrame({'time': times, 'value': values})

# plot bar chart
sns.barplot(x='value', y='time', data=df)

# format y-label
plt.gca().invert_yaxis()
plt.yticks(df.index, [t.strftime('%H:%M:%S') for t in df['time']])
plt.ylabel('Time (HH:MM:SS)')

# display plot
plt.show()
